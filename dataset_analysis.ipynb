# %%
from dataclasses import dataclass


@dataclass
class ToolsReport:
    cve_bin_tool: int
    docker_scout: int
    docker_scout_sbom: int
    grype: int
    grype_sbom: int
    snyk: int
    trivy: int
    trivy_sbom: int

# %%
import os


def get_latest_file_in_folder(folder_path: str) -> str:
    files = os.listdir(folder_path)
    return folder_path + "/" + sorted(files)[-1]

# %%
import json

from schemas.cve import CVE


def read_vulnerabilities_from_file(report_path: str) -> list[CVE]:
    with open(report_path, "r") as txt:
        vulnerabilities = json.load(txt)
    return list(map(lambda raw_vulnerability: CVE(**raw_vulnerability), vulnerabilities))

# %%
def get_reports_on_images(image_name: str) -> ToolsReport:
    folder = f"reports/{image_name}"

    cve_bin_tool_latest_report = get_latest_file_in_folder(folder + "/cve-bin-tool")
    docker_scout_latest_report = get_latest_file_in_folder(folder + "/docker-scout")
    docker_scout_sbom_latest_report = get_latest_file_in_folder(folder + "/docker-scout-sbom")
    grype_latest_report = get_latest_file_in_folder(folder + "/grype")
    grype_sbom_latest_report = get_latest_file_in_folder(folder + "/grype-sbom")
    snyk_latest_report = get_latest_file_in_folder(folder + "/snyk")
    trivy_latest_report = get_latest_file_in_folder(folder + "/trivy")
    trivy_sbom_latest_report = get_latest_file_in_folder(folder + "/trivy-sbom")

    cve_bin_tool_vulnerability: list[CVE] = read_vulnerabilities_from_file(cve_bin_tool_latest_report)
    docker_scout_vulnerability: list[CVE] = read_vulnerabilities_from_file(docker_scout_latest_report)
    docker_scout_sbom_vulnerability: list[CVE] = read_vulnerabilities_from_file(docker_scout_sbom_latest_report)
    grype_vulnerability: list[CVE] = read_vulnerabilities_from_file(grype_latest_report)
    grype_sbom_vulnerability: list[CVE] = read_vulnerabilities_from_file(grype_sbom_latest_report)
    snyk_vulnerability: list[CVE] = read_vulnerabilities_from_file(snyk_latest_report)
    trivy_vulnerability: list[CVE] = read_vulnerabilities_from_file(trivy_latest_report)
    trivy_sbom_vulnerability: list[CVE] = read_vulnerabilities_from_file(trivy_sbom_latest_report)

    return ToolsReport(
        cve_bin_tool=cve_bin_tool_vulnerability,
        docker_scout=docker_scout_vulnerability,
        docker_scout_sbom=docker_scout_sbom_vulnerability,
        grype=grype_vulnerability,
        grype_sbom=grype_sbom_vulnerability,
        snyk=snyk_vulnerability,
        trivy=trivy_vulnerability,
        trivy_sbom=trivy_sbom_vulnerability,
    )

# %%
images = os.listdir("reports")
images = list(filter(lambda image: not image.startswith("."), images))

# %%
data = {
    "Image": [],
    "CVE-bin-tool": [],
    "Docker Scout": [],
    "Docker Scout SBOM": [],
    "Grype": [],
    "Grype SBOM": [],
    "Snyk": [],
    "Trivy": [],
    "Trivy SBOM": [],
}

# %%
for image in images:
    image_report = get_reports_on_images(image)

    data["Image"].append(image)
    data["CVE-bin-tool"].append(len(image_report.cve_bin_tool))
    data["Docker Scout"].append(len(image_report.docker_scout))
    data["Docker Scout SBOM"].append(len(image_report.docker_scout_sbom))
    data["Grype"].append(len(image_report.grype))
    data["Grype SBOM"].append(len(image_report.grype_sbom))
    data["Snyk"].append(len(image_report.snyk))
    data["Trivy"].append(len(image_report.trivy))
    data["Trivy SBOM"].append(len(image_report.trivy_sbom))

# %%
data
# Out:
# {'Image': ['tensorflow_tensorflow:nightly',
#   'vulhub_adminer:4.7.8',
#   'karljohns0n_nginx-more:php-8.2-nodejs',
#   'pheblar_flask_python_currency-weather_app:8149f6b91098ab20986e2f92e83d4606232d3bdd',
#   'genedna_mega:mono-ui-0.1-pre-release',
#   'dockerhubaneo_armonik_pollingagent:0.33.0-SNAPSHOT.53.edf2da3a',
#   'consul:1.15.4',
#   'mateuszskowron21_metrics-exporter:v1.0',
#   'vulhub_aria2:1.18.8',
#   'httpd:2.4.62',
#   'vulhub_celery:3.1.23',
#   'snilsumelis_hello-world-for-argocd:eb3214e',
#   'mariadb:11',
#   'jfcoz_blog:sha-b4a1160',
#   'vulhub_git:2.12.2-with-openssh',
#   'busybox:1.37',
#   'registry:2',
#   'hexlo_terraria-tmodloader-server:0.1.0.0',
#   'rabbitmq:4',
#   'ubuntu:25.04',
#   'memcached:1.6.32',
#   'vulhub_bash:4.3.0-with-httpd',
#   'redis:7.4',
#   'kolejka_satori:judge',
#   'vulhub_activemq:5.17.3',
#   'node:23',
#   'alpine:3.20',
#   'centos:centos7',
#   'postgres:16.6',
#   'icoy_kube-combo-base:v0.0.7-amd64',
#   'torizon_qt6-wayland-imx8:4-rc',
#   'upswot_upswot.api:6.0.2.0',
#   'rezcarbon_memorycortex:1.1.9-fixed',
#   'nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0a35f24cf169',
#   'vulhub_cacti:1.2.22',
#   'elsamhaa_alpine:1',
#   'passimx_chats-frontend:0.0.1',
#   'jarebear_hbni-audio-archive:2025.03.23.13',
#   'vulhub_appweb:7.0.1',
#   'solvworld_web-app:1.0',
#   'breuner_elbencho:master-ubuntu1804',
#   'vulhub_apisix:2.9',
#   'socrata_java-focal:17',
#   'frostfree_kittygram_backend:v0.1',
#   'php:8.2',
#   'besscroft_picimpact:v2.0.2',
#   'debian:12',
#   'vulhub_cups-browsed:2.0.1',
#   'adysis_vector:v1.0.1',
#   'enmanuelmoreira_docker-ansible-debian:12-arm64',
#   'phatluu313_el-fe:0ebef20b',
#   'myonara_webmud3:unitopia',
#   'ngshiheng_cafireshistorydb:20250413',
#   '1maa_erlang:21-alpine',
#   'domboeckli_sdjpa-hibernate-dao:0.0.1_feature_fix_h2_console-SNAPSHOT',
#   'python:3.13',
#   'nginx:1.27',
#   'influxdb:1.11.8',
#   'mongo:8.0',
#   'w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46bfcc08faac'],
#  'CVE-bin-tool': [88,
#   106,
#   363,
#   16,
#   5,
#   0,
#   37,
#   13,
#   276,
#   18,
#   331,
#   19,
#   85,
#   1,
#   221,
#   0,
#   14,
#   218,
#   38,
#   34,
#   0,
#   231,
#   52,
#   73,
#   184,
#   111,
#   4,
#   790,
#   50,
#   0,
#   59,
#   46,
#   97,
#   165,
#   153,
#   4,
#   7,
#   132,
#   339,
#   198,
#   132,
#   790,
#   90,
#   171,
#   3,
#   13,
#   0,
#   138,
#   5,
#   54,
#   471,
#   30,
#   145,
#   29,
#   36,
#   112,
#   67,
#   46,
#   85,
#   75],
#  'Docker Scout': [1510,
#   212,
#   7,
#   11,
#   0,
#   24,
#   50,
#   32,
#   0,
#   38,
#   9,
#   1,
#   84,
#   75,
#   0,
#   0,
#   21,
#   174,
#   25,
#   0,
#   14,
#   0,
#   74,
#   620,
#   182,
#   132,
#   0,
#   98,
#   91,
#   68,
#   99,
#   20,
#   59,
#   133,
#   262,
#   29,
#   7,
#   116,
#   0,
#   192,
#   0,
#   98,
#   1408,
#   185,
#   66,
#   5,
#   14,
#   119,
#   35,
#   84,
#   16,
#   21,
#   83,
#   19,
#   3,
#   143,
#   54,
#   42,
#   83,
#   51],
#  'Docker Scout SBOM': [1510,
#   212,
#   7,
#   11,
#   0,
#   24,
#   50,
#   32,
#   0,
#   38,
#   9,
#   1,
#   84,
#   75,
#   0,
#   0,
#   21,
#   238,
#   25,
#   0,
#   14,
#   0,
#   74,
#   638,
#   182,
#   131,
#   0,
#   68,
#   91,
#   68,
#   109,
#   20,
#   59,
#   133,
#   383,
#   29,
#   7,
#   116,
#   0,
#   194,
#   0,
#   68,
#   1408,
#   184,
#   66,
#   5,
#   14,
#   119,
#   35,
#   84,
#   16,
#   24,
#   83,
#   19,
#   3,
#   142,
#   54,
#   42,
#   104,
#   51],
#  'Grype': [2025,
#   3658,
#   297,
#   13,
#   0,
#   72,
#   77,
#   103,
#   468,
#   132,
#   521,
#   1,
#   724,
#   965,
#   482,
#   0,
#   0,
#   403,
#   41,
#   0,
#   75,
#   464,
#   135,
#   1502,
#   433,
#   1526,
#   0,
#   1207,
#   221,
#   278,
#   3354,
#   82,
#   135,
#   1042,
#   3900,
#   118,
#   13,
#   521,
#   859,
#   3210,
#   130,
#   1207,
#   1636,
#   1985,
#   1131,
#   13,
#   75,
#   2024,
#   122,
#   855,
#   2676,
#   62,
#   246,
#   52,
#   46,
#   1562,
#   154,
#   158,
#   138,
#   886],
#  'Grype SBOM': [2036,
#   3658,
#   622,
#   13,
#   0,
#   72,
#   77,
#   103,
#   468,
#   132,
#   521,
#   1,
#   724,
#   965,
#   482,
#   0,
#   22,
#   403,
#   41,
#   0,
#   75,
#   464,
#   135,
#   1518,
#   433,
#   1526,
#   0,
#   1207,
#   221,
#   284,
#   3354,
#   82,
#   135,
#   1042,
#   3900,
#   118,
#   13,
#   521,
#   859,
#   3210,
#   130,
#   1207,
#   1651,
#   1985,
#   1131,
#   13,
#   75,
#   2024,
#   122,
#   877,
#   2677,
#   62,
#   246,
#   52,
#   46,
#   1562,
#   154,
#   158,
#   138,
#   886],
#  'Snyk': [465,
#   1587,
#   0,
#   0,
#   0,
#   158,
#   0,
#   216,
#   1222,
#   288,
#   962,
#   3,
#   154,
#   721,
#   1096,
#   0,
#   0,
#   874,
#   67,
#   0,
#   161,
#   761,
#   164,
#   148,
#   659,
#   1278,
#   0,
#   1201,
#   347,
#   409,
#   0,
#   168,
#   233,
#   1010,
#   1985,
#   252,
#   20,
#   1118,
#   767,
#   1671,
#   130,
#   1201,
#   188,
#   1394,
#   654,
#   27,
#   163,
#   895,
#   238,
#   0,
#   3085,
#   74,
#   458,
#   0,
#   9,
#   1280,
#   321,
#   301,
#   157,
#   525],
#  'Trivy': [1762,
#   3666,
#   5,
#   11,
#   0,
#   77,
#   43,
#   103,
#   309,
#   135,
#   311,
#   1,
#   115,
#   971,
#   560,
#   0,
#   19,
#   392,
#   28,
#   0,
#   80,
#   258,
#   138,
#   616,
#   404,
#   1530,
#   0,
#   1208,
#   224,
#   283,
#   3361,
#   565,
#   135,
#   1043,
#   3909,
#   77,
#   7,
#   516,
#   498,
#   3219,
#   0,
#   1208,
#   1410,
#   1990,
#   1134,
#   8,
#   80,
#   2005,
#   127,
#   861,
#   6437,
#   27,
#   235,
#   33,
#   8,
#   1565,
#   159,
#   152,
#   110,
#   890],
#  'Trivy SBOM': [53,
#   178,
#   7,
#   11,
#   0,
#   11,
#   43,
#   14,
#   73,
#   20,
#   65,
#   1,
#   66,
#   66,
#   68,
#   0,
#   19,
#   75,
#   17,
#   0,
#   11,
#   59,
#   69,
#   35,
#   117,
#   79,
#   0,
#   1208,
#   81,
#   79,
#   57,
#   16,
#   34,
#   93,
#   182,
#   22,
#   5,
#   67,
#   37,
#   141,
#   0,
#   1208,
#   42,
#   134,
#   61,
#   3,
#   11,
#   44,
#   17,
#   66,
#   272,
#   17,
#   41,
#   4,
#   2,
#   80,
#   29,
#   26,
#   68,
#   38]}

# %%
import pandas as pd


df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 Image  CVE-bin-tool  \
# 0                       tensorflow_tensorflow:nightly            88
# 1                                vulhub_adminer:4.7.8           106
# 2               karljohns0n_nginx-more:php-8.2-nodejs           363
# 3   pheblar_flask_python_currency-weather_app:8149...            16
# 4                genedna_mega:mono-ui-0.1-pre-release             5
# 5   dockerhubaneo_armonik_pollingagent:0.33.0-SNAP...             0
# 6                                       consul:1.15.4            37
# 7              mateuszskowron21_metrics-exporter:v1.0            13
# 8                                 vulhub_aria2:1.18.8           276
# 9                                        httpd:2.4.62            18
# 10                               vulhub_celery:3.1.23           331
# 11         snilsumelis_hello-world-for-argocd:eb3214e            19
# 12                                         mariadb:11            85
# 13                             jfcoz_blog:sha-b4a1160             1
# 14                     vulhub_git:2.12.2-with-openssh           221
# 15                                       busybox:1.37             0
# 16                                         registry:2            14
# 17           hexlo_terraria-tmodloader-server:0.1.0.0           218
# 18                                         rabbitmq:4            38
# 19                                       ubuntu:25.04            34
# 20                                   memcached:1.6.32             0
# 21                       vulhub_bash:4.3.0-with-httpd           231
# 22                                          redis:7.4            52
# 23                               kolejka_satori:judge            73
# 24                             vulhub_activemq:5.17.3           184
# 25                                            node:23           111
# 26                                        alpine:3.20             4
# 27                                     centos:centos7           790
# 28                                      postgres:16.6            50
# 29                  icoy_kube-combo-base:v0.0.7-amd64             0
# 30                      torizon_qt6-wayland-imx8:4-rc            59
# 31                          upswot_upswot.api:6.0.2.0            46
# 32                 rezcarbon_memorycortex:1.1.9-fixed            97
# 33  nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0...           165
# 34                                vulhub_cacti:1.2.22           153
# 35                                  elsamhaa_alpine:1             4
# 36                       passimx_chats-frontend:0.0.1             7
# 37          jarebear_hbni-audio-archive:2025.03.23.13           132
# 38                                vulhub_appweb:7.0.1           339
# 39                              solvworld_web-app:1.0           198
# 40                 breuner_elbencho:master-ubuntu1804           132
# 41                                  vulhub_apisix:2.9           790
# 42                              socrata_java-focal:17            90
# 43                   frostfree_kittygram_backend:v0.1           171
# 44                                            php:8.2             3
# 45                         besscroft_picimpact:v2.0.2            13
# 46                                          debian:12             0
# 47                          vulhub_cups-browsed:2.0.1           138
# 48                               adysis_vector:v1.0.1             5
# 49     enmanuelmoreira_docker-ansible-debian:12-arm64            54
# 50                          phatluu313_el-fe:0ebef20b           471
# 51                           myonara_webmud3:unitopia            30
# 52                ngshiheng_cafireshistorydb:20250413           145
# 53                              1maa_erlang:21-alpine            29
# 54  domboeckli_sdjpa-hibernate-dao:0.0.1_feature_f...            36
# 55                                        python:3.13           112
# 56                                         nginx:1.27            67
# 57                                    influxdb:1.11.8            46
# 58                                          mongo:8.0            85
# 59  w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46...            75
#
#     Docker Scout  Docker Scout SBOM  Grype  Grype SBOM  Snyk  Trivy  \
# 0           1510               1510   2025        2036   465   1762
# 1            212                212   3658        3658  1587   3666
# 2              7                  7    297         622     0      5
# 3             11                 11     13          13     0     11
# 4              0                  0      0           0     0      0
# 5             24                 24     72          72   158     77
# 6             50                 50     77          77     0     43
# 7             32                 32    103         103   216    103
# 8              0                  0    468         468  1222    309
# 9             38                 38    132         132   288    135
# 10             9                  9    521         521   962    311
# 11             1                  1      1           1     3      1
# 12            84                 84    724         724   154    115
# 13            75                 75    965         965   721    971
# 14             0                  0    482         482  1096    560
# 15             0                  0      0           0     0      0
# 16            21                 21      0          22     0     19
# 17           174                238    403         403   874    392
# 18            25                 25     41          41    67     28
# 19             0                  0      0           0     0      0
# 20            14                 14     75          75   161     80
# 21             0                  0    464         464   761    258
# 22            74                 74    135         135   164    138
# 23           620                638   1502        1518   148    616
# 24           182                182    433         433   659    404
# 25           132                131   1526        1526  1278   1530
# 26             0                  0      0           0     0      0
# 27            98                 68   1207        1207  1201   1208
# 28            91                 91    221         221   347    224
# 29            68                 68    278         284   409    283
# 30            99                109   3354        3354     0   3361
# 31            20                 20     82          82   168    565
# 32            59                 59    135         135   233    135
# 33           133                133   1042        1042  1010   1043
# 34           262                383   3900        3900  1985   3909
# 35            29                 29    118         118   252     77
# 36             7                  7     13          13    20      7
# 37           116                116    521         521  1118    516
# 38             0                  0    859         859   767    498
# 39           192                194   3210        3210  1671   3219
# 40             0                  0    130         130   130      0
# 41            98                 68   1207        1207  1201   1208
# 42          1408               1408   1636        1651   188   1410
# 43           185                184   1985        1985  1394   1990
# 44            66                 66   1131        1131   654   1134
# 45             5                  5     13          13    27      8
# 46            14                 14     75          75   163     80
# 47           119                119   2024        2024   895   2005
# 48            35                 35    122         122   238    127
# 49            84                 84    855         877     0    861
# 50            16                 16   2676        2677  3085   6437
# 51            21                 24     62          62    74     27
# 52            83                 83    246         246   458    235
# 53            19                 19     52          52     0     33
# 54             3                  3     46          46     9      8
# 55           143                142   1562        1562  1280   1565
# 56            54                 54    154         154   321    159
# 57            42                 42    158         158   301    152
# 58            83                104    138         138   157    110
# 59            51                 51    886         886   525    890
#
#     Trivy SBOM
# 0           53
# 1          178
# 2            7
# 3           11
# 4            0
# 5           11
# 6           43
# 7           14
# 8           73
# 9           20
# 10          65
# 11           1
# 12          66
# 13          66
# 14          68
# 15           0
# 16          19
# 17          75
# 18          17
# 19           0
# 20          11
# 21          59
# 22          69
# 23          35
# 24         117
# 25          79
# 26           0
# 27        1208
# 28          81
# 29          79
# 30          57
# 31          16
# 32          34
# 33          93
# 34         182
# 35          22
# 36           5
# 37          67
# 38          37
# 39         141
# 40           0
# 41        1208
# 42          42
# 43         134
# 44          61
# 45           3
# 46          11
# 47          44
# 48          17
# 49          66
# 50         272
# 51          17
# 52          41
# 53           4
# 54           2
# 55          80
# 56          29
# 57          26
# 58          68
# 59          38

# %%
paper_data = {
    "Image": [],
    "Trivy": [],
    "CVE-bin-tool": [],
    "Unique CVE-bin-tool": []
}

# %%
from utils.cve_utils import find_unique_vulnerabilities


for image in images:
    image_report = get_reports_on_images(image)

    paper_data["Image"].append(image)
    paper_data["Trivy"].append(len(image_report.trivy))
    paper_data["CVE-bin-tool"].append(len(image_report.cve_bin_tool))
    paper_data["Unique CVE-bin-tool"].append(
        len(find_unique_vulnerabilities(
            image_report.trivy,
            image_report.cve_bin_tool,
        ))
    )

# %%
paper_data
# Out:
# {'Image': ['tensorflow_tensorflow:nightly',
#   'vulhub_adminer:4.7.8',
#   'karljohns0n_nginx-more:php-8.2-nodejs',
#   'pheblar_flask_python_currency-weather_app:8149f6b91098ab20986e2f92e83d4606232d3bdd',
#   'genedna_mega:mono-ui-0.1-pre-release',
#   'dockerhubaneo_armonik_pollingagent:0.33.0-SNAPSHOT.53.edf2da3a',
#   'consul:1.15.4',
#   'mateuszskowron21_metrics-exporter:v1.0',
#   'vulhub_aria2:1.18.8',
#   'httpd:2.4.62',
#   'vulhub_celery:3.1.23',
#   'snilsumelis_hello-world-for-argocd:eb3214e',
#   'mariadb:11',
#   'jfcoz_blog:sha-b4a1160',
#   'vulhub_git:2.12.2-with-openssh',
#   'busybox:1.37',
#   'registry:2',
#   'hexlo_terraria-tmodloader-server:0.1.0.0',
#   'rabbitmq:4',
#   'ubuntu:25.04',
#   'memcached:1.6.32',
#   'vulhub_bash:4.3.0-with-httpd',
#   'redis:7.4',
#   'kolejka_satori:judge',
#   'vulhub_activemq:5.17.3',
#   'node:23',
#   'alpine:3.20',
#   'centos:centos7',
#   'postgres:16.6',
#   'icoy_kube-combo-base:v0.0.7-amd64',
#   'torizon_qt6-wayland-imx8:4-rc',
#   'upswot_upswot.api:6.0.2.0',
#   'rezcarbon_memorycortex:1.1.9-fixed',
#   'nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0a35f24cf169',
#   'vulhub_cacti:1.2.22',
#   'elsamhaa_alpine:1',
#   'passimx_chats-frontend:0.0.1',
#   'jarebear_hbni-audio-archive:2025.03.23.13',
#   'vulhub_appweb:7.0.1',
#   'solvworld_web-app:1.0',
#   'breuner_elbencho:master-ubuntu1804',
#   'vulhub_apisix:2.9',
#   'socrata_java-focal:17',
#   'frostfree_kittygram_backend:v0.1',
#   'php:8.2',
#   'besscroft_picimpact:v2.0.2',
#   'debian:12',
#   'vulhub_cups-browsed:2.0.1',
#   'adysis_vector:v1.0.1',
#   'enmanuelmoreira_docker-ansible-debian:12-arm64',
#   'phatluu313_el-fe:0ebef20b',
#   'myonara_webmud3:unitopia',
#   'ngshiheng_cafireshistorydb:20250413',
#   '1maa_erlang:21-alpine',
#   'domboeckli_sdjpa-hibernate-dao:0.0.1_feature_fix_h2_console-SNAPSHOT',
#   'python:3.13',
#   'nginx:1.27',
#   'influxdb:1.11.8',
#   'mongo:8.0',
#   'w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46bfcc08faac'],
#  'Trivy': [1762,
#   3666,
#   5,
#   11,
#   0,
#   77,
#   43,
#   103,
#   309,
#   135,
#   311,
#   1,
#   115,
#   971,
#   560,
#   0,
#   19,
#   392,
#   28,
#   0,
#   80,
#   258,
#   138,
#   616,
#   404,
#   1530,
#   0,
#   1208,
#   224,
#   283,
#   3361,
#   565,
#   135,
#   1043,
#   3909,
#   77,
#   7,
#   516,
#   498,
#   3219,
#   0,
#   1208,
#   1410,
#   1990,
#   1134,
#   8,
#   80,
#   2005,
#   127,
#   861,
#   6437,
#   27,
#   235,
#   33,
#   8,
#   1565,
#   159,
#   152,
#   110,
#   890],
#  'CVE-bin-tool': [88,
#   106,
#   363,
#   16,
#   5,
#   0,
#   37,
#   13,
#   276,
#   18,
#   331,
#   19,
#   85,
#   1,
#   221,
#   0,
#   14,
#   218,
#   38,
#   34,
#   0,
#   231,
#   52,
#   73,
#   184,
#   111,
#   4,
#   790,
#   50,
#   0,
#   59,
#   46,
#   97,
#   165,
#   153,
#   4,
#   7,
#   132,
#   339,
#   198,
#   132,
#   790,
#   90,
#   171,
#   3,
#   13,
#   0,
#   138,
#   5,
#   54,
#   471,
#   30,
#   145,
#   29,
#   36,
#   112,
#   67,
#   46,
#   85,
#   75],
#  'Unique CVE-bin-tool': [87,
#   72,
#   363,
#   3,
#   5,
#   0,
#   24,
#   11,
#   231,
#   17,
#   273,
#   19,
#   40,
#   1,
#   105,
#   0,
#   8,
#   123,
#   37,
#   34,
#   0,
#   196,
#   8,
#   71,
#   85,
#   96,
#   4,
#   415,
#   6,
#   0,
#   37,
#   40,
#   82,
#   128,
#   79,
#   0,
#   6,
#   115,
#   294,
#   150,
#   132,
#   415,
#   88,
#   83,
#   3,
#   13,
#   0,
#   94,
#   5,
#   40,
#   332,
#   20,
#   100,
#   13,
#   36,
#   97,
#   55,
#   41,
#   40,
#   71]}

# %%
import pandas as pd
paper_df = pd.DataFrame(paper_data)

# %%
paper_df
# Out:
#                                                 Image  Trivy  CVE-bin-tool  \
# 0                       tensorflow_tensorflow:nightly   1762            88
# 1                                vulhub_adminer:4.7.8   3666           106
# 2               karljohns0n_nginx-more:php-8.2-nodejs      5           363
# 3   pheblar_flask_python_currency-weather_app:8149...     11            16
# 4                genedna_mega:mono-ui-0.1-pre-release      0             5
# 5   dockerhubaneo_armonik_pollingagent:0.33.0-SNAP...     77             0
# 6                                       consul:1.15.4     43            37
# 7              mateuszskowron21_metrics-exporter:v1.0    103            13
# 8                                 vulhub_aria2:1.18.8    309           276
# 9                                        httpd:2.4.62    135            18
# 10                               vulhub_celery:3.1.23    311           331
# 11         snilsumelis_hello-world-for-argocd:eb3214e      1            19
# 12                                         mariadb:11    115            85
# 13                             jfcoz_blog:sha-b4a1160    971             1
# 14                     vulhub_git:2.12.2-with-openssh    560           221
# 15                                       busybox:1.37      0             0
# 16                                         registry:2     19            14
# 17           hexlo_terraria-tmodloader-server:0.1.0.0    392           218
# 18                                         rabbitmq:4     28            38
# 19                                       ubuntu:25.04      0            34
# 20                                   memcached:1.6.32     80             0
# 21                       vulhub_bash:4.3.0-with-httpd    258           231
# 22                                          redis:7.4    138            52
# 23                               kolejka_satori:judge    616            73
# 24                             vulhub_activemq:5.17.3    404           184
# 25                                            node:23   1530           111
# 26                                        alpine:3.20      0             4
# 27                                     centos:centos7   1208           790
# 28                                      postgres:16.6    224            50
# 29                  icoy_kube-combo-base:v0.0.7-amd64    283             0
# 30                      torizon_qt6-wayland-imx8:4-rc   3361            59
# 31                          upswot_upswot.api:6.0.2.0    565            46
# 32                 rezcarbon_memorycortex:1.1.9-fixed    135            97
# 33  nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0...   1043           165
# 34                                vulhub_cacti:1.2.22   3909           153
# 35                                  elsamhaa_alpine:1     77             4
# 36                       passimx_chats-frontend:0.0.1      7             7
# 37          jarebear_hbni-audio-archive:2025.03.23.13    516           132
# 38                                vulhub_appweb:7.0.1    498           339
# 39                              solvworld_web-app:1.0   3219           198
# 40                 breuner_elbencho:master-ubuntu1804      0           132
# 41                                  vulhub_apisix:2.9   1208           790
# 42                              socrata_java-focal:17   1410            90
# 43                   frostfree_kittygram_backend:v0.1   1990           171
# 44                                            php:8.2   1134             3
# 45                         besscroft_picimpact:v2.0.2      8            13
# 46                                          debian:12     80             0
# 47                          vulhub_cups-browsed:2.0.1   2005           138
# 48                               adysis_vector:v1.0.1    127             5
# 49     enmanuelmoreira_docker-ansible-debian:12-arm64    861            54
# 50                          phatluu313_el-fe:0ebef20b   6437           471
# 51                           myonara_webmud3:unitopia     27            30
# 52                ngshiheng_cafireshistorydb:20250413    235           145
# 53                              1maa_erlang:21-alpine     33            29
# 54  domboeckli_sdjpa-hibernate-dao:0.0.1_feature_f...      8            36
# 55                                        python:3.13   1565           112
# 56                                         nginx:1.27    159            67
# 57                                    influxdb:1.11.8    152            46
# 58                                          mongo:8.0    110            85
# 59  w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46...    890            75
#
#     Unique CVE-bin-tool
# 0                    87
# 1                    72
# 2                   363
# 3                     3
# 4                     5
# 5                     0
# 6                    24
# 7                    11
# 8                   231
# 9                    17
# 10                  273
# 11                   19
# 12                   40
# 13                    1
# 14                  105
# 15                    0
# 16                    8
# 17                  123
# 18                   37
# 19                   34
# 20                    0
# 21                  196
# 22                    8
# 23                   71
# 24                   85
# 25                   96
# 26                    4
# 27                  415
# 28                    6
# 29                    0
# 30                   37
# 31                   40
# 32                   82
# 33                  128
# 34                   79
# 35                    0
# 36                    6
# 37                  115
# 38                  294
# 39                  150
# 40                  132
# 41                  415
# 42                   88
# 43                   83
# 44                    3
# 45                   13
# 46                    0
# 47                   94
# 48                    5
# 49                   40
# 50                  332
# 51                   20
# 52                  100
# 53                   13
# 54                   36
# 55                   97
# 56                   55
# 57                   41
# 58                   40
# 59                   71

# %%
min_value = paper_df["Unique CVE-bin-tool"].min()
max_value = paper_df["Unique CVE-bin-tool"].max()
median_value = paper_df["Unique CVE-bin-tool"].median()

# %%
print(f"Min value: {min_value}")
print(f"Max value: {max_value}")
print(f"Median value: {median_value}")
# Out:
# Min value: 0
# Max value: 415
# Median value: 40.0

# %%
most_pulled_images = [
    "memcached:1.6.32",
    "tensorflow_tensorflow:nightly",
    "nginx:1.27",
    "busybox:1.37",
    "alpine:3.20",
    "ubuntu:25.04",
    "redis:7.4",
    "postgres:16.6",
    "python:3.13",
    "node:23",
    "httpd:2.4.62",
    "mongo:8.0",
    "rabbitmq:4",
    "mariadb:11",
    "registry:2",
    "debian:12",
    "php:8.2",
    "centos:centos7",
    "influxdb:1.11.8",
    "consul:1.15.4",
]

# %%
paper_most_pulled_data = {
    "Image": [],
    "Trivy": [],
    "CVE-bin-tool": [],
    "Unique CVE-bin-tool": []
}

# %%
for image in most_pulled_images:
    image_report = get_reports_on_images(image)

    paper_most_pulled_data["Image"].append(image)
    paper_most_pulled_data["Trivy"].append(len(image_report.trivy))
    paper_most_pulled_data["CVE-bin-tool"].append(len(image_report.cve_bin_tool))
    paper_most_pulled_data["Unique CVE-bin-tool"].append(
        len(find_unique_vulnerabilities(
            image_report.trivy,
            image_report.cve_bin_tool,
        ))
    )

# %%
paper_most_pulled_df = pd.DataFrame(paper_most_pulled_data)

# %%
paper_most_pulled_df
# Out:
#                             Image  Trivy  CVE-bin-tool  Unique CVE-bin-tool
# 0                memcached:1.6.32     80             0                    0
# 1   tensorflow_tensorflow:nightly   1762            88                   87
# 2                      nginx:1.27    159            67                   55
# 3                    busybox:1.37      0             0                    0
# 4                     alpine:3.20      0             4                    4
# 5                    ubuntu:25.04      0            34                   34
# 6                       redis:7.4    138            52                    8
# 7                   postgres:16.6    224            50                    6
# 8                     python:3.13   1565           112                   97
# 9                         node:23   1530           111                   96
# 10                   httpd:2.4.62    135            18                   17
# 11                      mongo:8.0    110            85                   40
# 12                     rabbitmq:4     28            38                   37
# 13                     mariadb:11    115            85                   40
# 14                     registry:2     19            14                    8
# 15                      debian:12     80             0                    0
# 16                        php:8.2   1134             3                    3
# 17                 centos:centos7   1208           790                  415
# 18                influxdb:1.11.8    152            46                   41
# 19                  consul:1.15.4     43            37                   24

# %%
max_most_pulled_value = paper_most_pulled_df["Unique CVE-bin-tool"].max()
median_most_pulled_value = paper_most_pulled_df["Unique CVE-bin-tool"].median()

# %%
print(f"Most pulled images, max: {max_most_pulled_value}")
print(f"Most pulled images, median: {median_most_pulled_value}")
# Out:
# Most pulled images, max: 415
# Most pulled images, median: 29.0

# %%
vulnerable_images = [
    "vulhub_activemq:5.17.3",
    "vulhub_adminer:4.7.8",
    "vulhub_apisix:2.9",
    "vulhub_appweb:7.0.1",
    "vulhub_aria2:1.18.8",
    "vulhub_bash:4.3.0-with-httpd",
    "vulhub_cacti:1.2.22",
    "vulhub_celery:3.1.23",
    "vulhub_cups-browsed:2.0.1",
    "vulhub_git:2.12.2-with-openssh",
]

# %%
paper_vulhub_data = {
    "Image": [],
    "Trivy": [],
    "CVE-bin-tool": [],
    "Unique CVE-bin-tool": []
}

# %%
for image in vulnerable_images:
    image_report = get_reports_on_images(image)

    paper_vulhub_data["Image"].append(image)
    paper_vulhub_data["Trivy"].append(len(image_report.trivy))
    paper_vulhub_data["CVE-bin-tool"].append(len(image_report.cve_bin_tool))
    paper_vulhub_data["Unique CVE-bin-tool"].append(
        len(find_unique_vulnerabilities(
            image_report.trivy,
            image_report.cve_bin_tool,
        ))
    )

# %%
paper_vulhub_df = pd.DataFrame(paper_vulhub_data)

# %%
paper_vulhub_df
# Out:
#                             Image  Trivy  CVE-bin-tool  Unique CVE-bin-tool
# 0          vulhub_activemq:5.17.3    404           184                   85
# 1            vulhub_adminer:4.7.8   3666           106                   72
# 2               vulhub_apisix:2.9   1208           790                  415
# 3             vulhub_appweb:7.0.1    498           339                  294
# 4             vulhub_aria2:1.18.8    309           276                  231
# 5    vulhub_bash:4.3.0-with-httpd    258           231                  196
# 6             vulhub_cacti:1.2.22   3909           153                   79
# 7            vulhub_celery:3.1.23    311           331                  273
# 8       vulhub_cups-browsed:2.0.1   2005           138                   94
# 9  vulhub_git:2.12.2-with-openssh    560           221                  105

# %%
max_vulnerable_images = paper_vulhub_df["Unique CVE-bin-tool"].max()
median_vulnerable_images = paper_vulhub_df["Unique CVE-bin-tool"].median()

# %%
print(f"Max vulnerable images: {max_vulnerable_images}")
print(f"Median vulnerable images: {median_vulnerable_images}")
# Out:
# Max vulnerable images: 415
# Median vulnerable images: 150.5

# %%
random_images = [
    "1maa_erlang:21-alpine",
    "adysis_vector:v1.0.1",
    "besscroft_picimpact:v2.0.2",
    "breuner_elbencho:master-ubuntu1804",
    "dockerhubaneo_armonik_pollingagent:0.33.0-SNAPSHOT.53.edf2da3a",
    "domboeckli_sdjpa-hibernate-dao:0.0.1_feature_fix_h2_console-SNAPSHOT",
    "elsamhaa_alpine:1",
    "enmanuelmoreira_docker-ansible-debian:12-arm64",
    "frostfree_kittygram_backend:v0.1",
    "genedna_mega:mono-ui-0.1-pre-release",
    "hexlo_terraria-tmodloader-server:0.1.0.0",
    "icoy_kube-combo-base:v0.0.7-amd64",
    "jarebear_hbni-audio-archive:2025.03.23.13",
    "jfcoz_blog:sha-b4a1160",
    "karljohns0n_nginx-more:php-8.2-nodejs",
    "kolejka_satori:judge",
    "mateuszskowron21_metrics-exporter:v1.0",
    "myonara_webmud3:unitopia",
    "nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0a35f24cf169",
    "ngshiheng_cafireshistorydb:20250413",
    "passimx_chats-frontend:0.0.1",
    "phatluu313_el-fe:0ebef20b",
    "pheblar_flask_python_currency-weather_app:8149f6b91098ab20986e2f92e83d4606232d3bdd",
    "w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46bfcc08faac",
    "rezcarbon_memorycortex:1.1.9-fixed",
    "snilsumelis_hello-world-for-argocd:eb3214e",
    "socrata_java-focal:17",
    "solvworld_web-app:1.0",
    "torizon_qt6-wayland-imx8:4-rc",
    "upswot_upswot.api:6.0.2.0",
]

# %%
paper_random_data = {
    "Image": [],
    "Trivy": [],
    "CVE-bin-tool": [],
    "Unique CVE-bin-tool": []
}

# %%
for image in random_images:
    image_report = get_reports_on_images(image)

    paper_random_data["Image"].append(image)
    paper_random_data["Trivy"].append(len(image_report.trivy))
    paper_random_data["CVE-bin-tool"].append(len(image_report.cve_bin_tool))
    paper_random_data["Unique CVE-bin-tool"].append(
        len(find_unique_vulnerabilities(
            image_report.trivy,
            image_report.cve_bin_tool,
        ))
    )

# %%
paper_random_df = pd.DataFrame(paper_random_data)

# %%
paper_random_df
# Out:
#                                                 Image  Trivy  CVE-bin-tool  \
# 0                               1maa_erlang:21-alpine     33            29
# 1                                adysis_vector:v1.0.1    127             5
# 2                          besscroft_picimpact:v2.0.2      8            13
# 3                  breuner_elbencho:master-ubuntu1804      0           132
# 4   dockerhubaneo_armonik_pollingagent:0.33.0-SNAP...     77             0
# 5   domboeckli_sdjpa-hibernate-dao:0.0.1_feature_f...      8            36
# 6                                   elsamhaa_alpine:1     77             4
# 7      enmanuelmoreira_docker-ansible-debian:12-arm64    861            54
# 8                    frostfree_kittygram_backend:v0.1   1990           171
# 9                genedna_mega:mono-ui-0.1-pre-release      0             5
# 10           hexlo_terraria-tmodloader-server:0.1.0.0    392           218
# 11                  icoy_kube-combo-base:v0.0.7-amd64    283             0
# 12          jarebear_hbni-audio-archive:2025.03.23.13    516           132
# 13                             jfcoz_blog:sha-b4a1160    971             1
# 14              karljohns0n_nginx-more:php-8.2-nodejs      5           363
# 15                               kolejka_satori:judge    616            73
# 16             mateuszskowron21_metrics-exporter:v1.0    103            13
# 17                           myonara_webmud3:unitopia     27            30
# 18  nathstevo97_ckan:302234cc4b597c3b0c8aa35e443f0...   1043           165
# 19                ngshiheng_cafireshistorydb:20250413    235           145
# 20                       passimx_chats-frontend:0.0.1      7             7
# 21                          phatluu313_el-fe:0ebef20b   6437           471
# 22  pheblar_flask_python_currency-weather_app:8149...     11            16
# 23  w3io_w3-runtime:fd97f250b78da05a9811ac997fdb46...    890            75
# 24                 rezcarbon_memorycortex:1.1.9-fixed    135            97
# 25         snilsumelis_hello-world-for-argocd:eb3214e      1            19
# 26                              socrata_java-focal:17   1410            90
# 27                              solvworld_web-app:1.0   3219           198
# 28                      torizon_qt6-wayland-imx8:4-rc   3361            59
# 29                          upswot_upswot.api:6.0.2.0    565            46
#
#     Unique CVE-bin-tool
# 0                    13
# 1                     5
# 2                    13
# 3                   132
# 4                     0
# 5                    36
# 6                     0
# 7                    40
# 8                    83
# 9                     5
# 10                  123
# 11                    0
# 12                  115
# 13                    1
# 14                  363
# 15                   71
# 16                   11
# 17                   20
# 18                  128
# 19                  100
# 20                    6
# 21                  332
# 22                    3
# 23                   71
# 24                   82
# 25                   19
# 26                   88
# 27                  150
# 28                   37
# 29                   40

# %%
max_paper_random = paper_random_df["Unique CVE-bin-tool"].max()
median_paper_random = paper_random_df["Unique CVE-bin-tool"].median()

# %%
print(f"Random images, max: {max_paper_random}")
print(f"Random images, median: {median_paper_random}")
# Out:
# Random images, max: 363
# Random images, median: 38.5
